# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import OrdinalEncoder
from fairlearn.datasets import fetch_adult
from scipy.io import loadmat
from scipy.spatial.distance import cdist
from lp_solver import run_connector_and_solve_lp
from min_cost_rounding import rounding_wrapper
from clustering_utils import give_rand_centers, lloyd, comp_cost
from main_wc import load_data, normalize_data,socially_fair_kmeans# assumed helper functions

# %%
import networkx as nx

G = nx.DiGraph()
G.add_node("a", demand=-1)
G.add_node("b", demand=1)
G.add_edge("a", "b", capacity=1, weight=0.4873)

cost, flow = nx.network_simplex(G)
print("Flow cost:", cost)

# %%
def test_lp_and_rounding(data_normalized, svar_all, centers, alpha_val=0.1, beta_val=0.1, lambda_param=0.5):
    """
    Run LP and min-cost rounding on given clustering centers.
    
    Parameters:
    - data_normalized: ndarray of shape (n, d), normalized input data
    - svar_all: 1D array of sensitive group labels (1 or 2)
    - centers: ndarray of shape (k, d), cluster centers from fair clustering
    - alpha_val, beta_val: slack parameters for each group
    - lambda_param: tradeoff between clustering cost and fairness
    
    Returns:
    - result: dictionary from rounding_wrapper with final assignment and cost details
    """

    # Step 1: Define alpha and beta dictionaries
    unique_groups = np.unique(svar_all)
    alpha = {h: alpha_val for h in unique_groups}
    beta = {h: beta_val for h in unique_groups}

    # Step 2: Solve LP
    lp_result = run_connector_and_solve_lp(
        df=pd.DataFrame(data_normalized),
        svar_all=svar_all,
        centers=centers,
        alpha=alpha,
        beta=beta,
        lambda_param=lambda_param
    )
    
    print("LP keys:", lp_result.keys())
    print("LP objective z:", lp_result.get("z"))
    print("LP x_frac shape:", lp_result["x_frac"].shape)
    print("LP x_frac sum:", np.sum(lp_result["x_frac"]))
    
    # Step 3: Build distance matrix
    distance_matrix = cdist(data_normalized, centers, metric="sqeuclidean")

    
    print("Calling rounding_wrapper...")
    # Step 4: Run rounding
    result = rounding_wrapper(
    lp_assignment=lp_result["x_frac"],
    distance_matrix=distance_matrix,
    color_labels=svar_all.to_numpy(), 
    num_clusters=centers.shape[0],
    num_colors=len(unique_groups),
    lp_objective=lp_result["z"],
    df=data_normalized,
    centers=centers
    )

    print("Rounding done!")
    
    # Step 5: Print result summary
    print("✅ LP objective:", lp_result["z"])
    print("🎯 Rounded objective:", result["objective"])
    print("📊 Cost ratio (rounded / LP):", result["cost_ratio"])

    return result

# %%
data_all, svar_all, _ = load_data("adult")
data_normalized = normalize_data(data_all)
centers = socially_fair_kmeans(data_normalized, svar_all, k=10)
print("Centers shape:", centers.shape)
# Out:
# Centers shape: (10, 14)

# %%
centers = socially_fair_kmeans(data_normalized, svar_all, k=10)
result = test_lp_and_rounding(data_normalized, svar_all, centers)
# Out:
# Version identifier: 22.1.1.0 | 2022-11-28 | 9160aff4d
# CPXPARAM_Read_DataCheck                          1
# Parallel mode: deterministic, using up to 4 threads for concurrent optimization:
#  * Starting dual Simplex on 1 thread...
#  * Starting Barrier on 3 threads...
# Tried aggregator 1 time.
# LP Presolve eliminated 80 rows and 60 columns.
# Reduced LP has 45224 rows, 452221 columns, and 904442 nonzeros.
# Presolve time = 0.83 sec. (322.72 ticks)
# Initializing dual steep norms . . .
#
# Iteration log . . .
# Iteration:     1   Dual objective     =             0.000000
# Perturbation started.
# Iteration:   101   Dual objective     =             0.000000
# Iteration:  1586   Dual objective     =             0.019020
# Iteration:  3071   Dual objective     =             0.020108
# Iteration:  4556   Dual objective     =             0.020917
# Iteration:  6041   Dual objective     =             0.021591
# Iteration:  7526   Dual objective     =             0.022249
# Iteration:  9011   Dual objective     =             0.022920
# Iteration: 10496   Dual objective     =             0.023355
# Iteration: 11981   Dual objective     =             0.023629
# Iteration: 13466   Dual objective     =             0.023909
# Iteration: 14951   Dual objective     =             0.024196
# Iteration: 16436   Dual objective     =             0.024475
# Iteration: 17921   Dual objective     =             0.035961
# Iteration: 19406   Dual objective     =             0.038118
# Iteration: 20891   Dual objective     =             0.039427
# Iteration: 22376   Dual objective     =             0.040520
# Iteration: 23861   Dual objective     =             0.041144
# Iteration: 25346   Dual objective     =             0.041527
# Iteration: 26831   Dual objective     =             1.673631
# Iteration: 28117   Dual objective     =             2.146354
# Iteration: 29403   Dual objective     =             2.577342
# Iteration: 30689   Dual objective     =             2.967055
# Iteration: 31975   Dual objective     =             3.226196
# Iteration: 33261   Dual objective     =             3.487967
# Iteration: 34547   Dual objective     =             3.697339
# Iteration: 35833   Dual objective     =             3.830695
# Iteration: 37119   Dual objective     =             3.909827
# Iteration: 38406   Dual objective     =             3.955142
# Iteration: 39891   Dual objective     =             3.955318
# Iteration: 41039   Dual objective     =             3.955578
# Iteration: 42093   Dual objective     =             3.956488
# Removing perturbation.
#
# Dual simplex solved model.
#
# LP keys: dict_keys(['x_frac', 'z'])
# LP objective z: 3.9356907252610265
# LP x_frac shape: (45222, 10)
# LP x_frac sum: 45222.0
# Calling rounding_wrapper...
# >>> Entered rounding_wrapper
# NF Rounding ...
# Total graph demand (should be 0): 0
# 📋 Node demand summary (non-zero only):
#   0: demand = -1
#   1: demand = -1
#   2: demand = -1
#   3: demand = -1
#   4: demand = -1
#   5: demand = -1
#   6: demand = -1
#   7: demand = -1
#   8: demand = -1
#   9: demand = -1
#   10: demand = -1
#   11: demand = -1
#   12: demand = -1
#   13: demand = -1
#   14: demand = -1
#   15: demand = -1
#   16: demand = -1
#   17: demand = -1
#   18: demand = -1
#   19: demand = -1
#   20: demand = -1
#   21: demand = -1
#   22: demand = -1
#   23: demand = -1
#   24: demand = -1
#   25: demand = -1
#   26: demand = -1
#   27: demand = -1
#   28: demand = -1
#   29: demand = -1
#   30: demand = -1
#   31: demand = -1
#   32: demand = -1
#   33: demand = -1
#   34: demand = -1
#   35: demand = -1
#   36: demand = -1
#   37: demand = -1
#   38: demand = -1
#   39: demand = -1
#   40: demand = -1
#   41: demand = -1
#   42: demand = -1
#   43: demand = -1
#   44: demand = -1
#   45: demand = -1
#   46: demand = -1
#   47: demand = -1
#   48: demand = -1
#   49: demand = -1
#   50: demand = -1
#   51: demand = -1
#   52: demand = -1
#   53: demand = -1
#   54: demand = -1
#   55: demand = -1
#   56: demand = -1
#   57: demand = -1
#   58: demand = -1
#   59: demand = -1
#   60: demand = -1
#   61: demand = -1
#   62: demand = -1
#   63: demand = -1
#   64: demand = -1
#   65: demand = -1
#   66: demand = -1
#   67: demand = -1
#   68: demand = -1
#   69: demand = -1
#   70: demand = -1
#   71: demand = -1
#   72: demand = -1
#   73: demand = -1
#   74: demand = -1
#   75: demand = -1
#   76: demand = -1
#   77: demand = -1
#   78: demand = -1
#   79: demand = -1
#   80: demand = -1
#   81: demand = -1
#   82: demand = -1
#   83: demand = -1
#   84: demand = -1
#   85: demand = -1
#   86: demand = -1
#   87: demand = -1
#   88: demand = -1
#   89: demand = -1
#   90: demand = -1
#   91: demand = -1
#   92: demand = -1
#   93: demand = -1
#   94: demand = -1
#   95: demand = -1
#   96: demand = -1
#   97: demand = -1
#   98: demand = -1
#   99: demand = -1
#   100: demand = -1
#   101: demand = -1
#   102: demand = -1
#   103: demand = -1
#   104: demand = -1
#   105: demand = -1
#   106: demand = -1
#   107: demand = -1
#   108: demand = -1
#   109: demand = -1
#   110: demand = -1
#   111: demand = -1
#   112: demand = -1
#   113: demand = -1
#   114: demand = -1
#   115: demand = -1
#   116: demand = -1
#   117: demand = -1
#   118: demand = -1
#   119: demand = -1
#   120: demand = -1
#   121: demand = -1
#   122: demand = -1
#   123: demand = -1
#   124: demand = -1
#   125: demand = -1
#   126: demand = -1
#   127: demand = -1
#   128: demand = -1
#   129: demand = -1
#   130: demand = -1
#   131: demand = -1
#   132: demand = -1
#   133: demand = -1
#   134: demand = -1
#   135: demand = -1
#   136: demand = -1
#   137: demand = -1
#   138: demand = -1
#   139: demand = -1
#   140: demand = -1
#   141: demand = -1
#   142: demand = -1
#   143: demand = -1
#   144: demand = -1
#   145: demand = -1
#   146: demand = -1
#   147: demand = -1
#   148: demand = -1
#   149: demand = -1
#   150: demand = -1
#   151: demand = -1
#   152: demand = -1
#   153: demand = -1
#   154: demand = -1
#   155: demand = -1
#   156: demand = -1
#   157: demand = -1
#   158: demand = -1
#   159: demand = -1
#   160: demand = -1
#   161: demand = -1
#   162: demand = -1
#   163: demand = -1
#   164: demand = -1
#   165: demand = -1
#   166: demand = -1
#   167: demand = -1
#   168: demand = -1
#   169: demand = -1
#   170: demand = -1
#   171: demand = -1
#   172: demand = -1
#   173: demand = -1
#   174: demand = -1
#   175: demand = -1
#   176: demand = -1
#   177: demand = -1
#   178: demand = -1
#   179: demand = -1
#   180: demand = -1
#   181: demand = -1
#   182: demand = -1
#   183: demand = -1
#   184: demand = -1
#   185: demand = -1
#   186: demand = -1
#   187: demand = -1
#   188: demand = -1
#   189: demand = -1
#   190: demand = -1
#   191: demand = -1
#   192: demand = -1
#   193: demand = -1
#   194: demand = -1
#   195: demand = -1
#   196: demand = -1
#   197: demand = -1
#   198: demand = -1
#   199: demand = -1
#   200: demand = -1
#   201: demand = -1
#   202: demand = -1
#   203: demand = -1
#   204: demand = -1
#   205: demand = -1
#   206: demand = -1
#   207: demand = -1
#   208: demand = -1
#   209: demand = -1
#   210: demand = -1
#   211: demand = -1
#   212: demand = -1
#   213: demand = -1
#   214: demand = -1
#   215: demand = -1
#   216: demand = -1
#   217: demand = -1
#   218: demand = -1
#   219: demand = -1
#   220: demand = -1
#   221: demand = -1
#   222: demand = -1
#   223: demand = -1
#   224: demand = -1
#   225: demand = -1
#   226: demand = -1
#   227: demand = -1
#   228: demand = -1
#   229: demand = -1
#   230: demand = -1
#   231: demand = -1
#   232: demand = -1
#   233: demand = -1
#   234: demand = -1
#   235: demand = -1
#   236: demand = -1
#   237: demand = -1
#   238: demand = -1
#   239: demand = -1
#   240: demand = -1
#   241: demand = -1
#   242: demand = -1
#   243: demand = -1
#   244: demand = -1
#   245: demand = -1
#   246: demand = -1
#   247: demand = -1
#   248: demand = -1
#   249: demand = -1
#   250: demand = -1
#   251: demand = -1
#   252: demand = -1
#   253: demand = -1
#   254: demand = -1
#   255: demand = -1
#   256: demand = -1
#   257: demand = -1
#   258: demand = -1
#   259: demand = -1
#   260: demand = -1
#   261: demand = -1
#   262: demand = -1
#   263: demand = -1
#   264: demand = -1
#   265: demand = -1
#   266: demand = -1
#   267: demand = -1
#   268: demand = -1
#   269: demand = -1
#   270: demand = -1
#   271: demand = -1
#   272: demand = -1
#   273: demand = -1
#   274: demand = -1
#   275: demand = -1
#   276: demand = -1
#   277: demand = -1
#   278: demand = -1
#   279: demand = -1
#   280: demand = -1
#   281: demand = -1
#   282: demand = -1
#   283: demand = -1
#   284: demand = -1
#   285: demand = -1
#   286: demand = -1
#   287: demand = -1
#   288: demand = -1
#   289: demand = -1
#   290: demand = -1
#   291: demand = -1
#   292: demand = -1
#   293: demand = -1
#   294: demand = -1
#   295: demand = -1
#   296: demand = -1
#   297: demand = -1
#   298: demand = -1
#   299: demand = -1
#   300: demand = -1
#   301: demand = -1
#   302: demand = -1
#   303: demand = -1
#   304: demand = -1
#   305: demand = -1
#   306: demand = -1
#   307: demand = -1
#   308: demand = -1
#   309: demand = -1
#   310: demand = -1
#   311: demand = -1
#   312: demand = -1
#   313: demand = -1
#   314: demand = -1
#   315: demand = -1
#   316: demand = -1
#   317: demand = -1
#   318: demand = -1
#   319: demand = -1
#   320: demand = -1
#   321: demand = -1
#   322: demand = -1
#   323: demand = -1
#   324: demand = -1
#   325: demand = -1
#   326: demand = -1
#   327: demand = -1
#   328: demand = -1
#   329: demand = -1
#   330: demand = -1
#   331: demand = -1
#   332: demand = -1
#   333: demand = -1
#   334: demand = -1
#   335: demand = -1
#   336: demand = -1
#   337: demand = -1
#   338: demand = -1
#   339: demand = -1
#   340: demand = -1
#   341: demand = -1
#   342: demand = -1
#   343: demand = -1
#   344: demand = -1
#   345: demand = -1
#   346: demand = -1
#   347: demand = -1
#   348: demand = -1
#   349: demand = -1
#   350: demand = -1
#   351: demand = -1
#   352: demand = -1
#   353: demand = -1
#   354: demand = -1
#   355: demand = -1
#   356: demand = -1
#   357: demand = -1
#   358: demand = -1
#   359: demand = -1
#   360: demand = -1
#   361: demand = -1
#   362: demand = -1
#   363: demand = -1
#   364: demand = -1
#   365: demand = -1
#   366: demand = -1
#   367: demand = -1
#   368: demand = -1
#   369: demand = -1
#   370: demand = -1
#   371: demand = -1
#   372: demand = -1
#   373: demand = -1
#   374: demand = -1
#   375: demand = -1
#   376: demand = -1
#   377: demand = -1
#   378: demand = -1
#   379: demand = -1
#   380: demand = -1
#   381: demand = -1
#   382: demand = -1
#   383: demand = -1
#   384: demand = -1
#   385: demand = -1
#   386: demand = -1
#   387: demand = -1
#   388: demand = -1
#   389: demand = -1
#   390: demand = -1
#   391: demand = -1
#   392: demand = -1
#   393: demand = -1
#   394: demand = -1
#   395: demand = -1
#   396: demand = -1
#   397: demand = -1
#   398: demand = -1
#   399: demand = -1
#   400: demand = -1
#   401: demand = -1
#   402: demand = -1
#   403: demand = -1
#   404: demand = -1
#   405: demand = -1
#   406: demand = -1
#   407: demand = -1
#   408: demand = -1
#   409: demand = -1
#   410: demand = -1
#   411: demand = -1
#   412: demand = -1
#   413: demand = -1
#   414: demand = -1
#   415: demand = -1
#   416: demand = -1
#   417: demand = -1
#   418: demand = -1
#   419: demand = -1
#   420: demand = -1
#   421: demand = -1
#   422: demand = -1
#   423: demand = -1
#   424: demand = -1
#   425: demand = -1
#   426: demand = -1
#   427: demand = -1
#   428: demand = -1
#   429: demand = -1
#   430: demand = -1
#   431: demand = -1
#   432: demand = -1
#   433: demand = -1
#   434: demand = -1
#   435: demand = -1
#   436: demand = -1
#   437: demand = -1
#   438: demand = -1
#   439: demand = -1
#   440: demand = -1
#   441: demand = -1
#   442: demand = -1
#   443: demand = -1
#   444: demand = -1
#   445: demand = -1
#   446: demand = -1
#   447: demand = -1
#   448: demand = -1
#   449: demand = -1
#   450: demand = -1
#   451: demand = -1
#   452: demand = -1
#   453: demand = -1
#   454: demand = -1
#   455: demand = -1
#   456: demand = -1
#   457: demand = -1
#   458: demand = -1
#   459: demand = -1
#   460: demand = -1
#   461: demand = -1
#   462: demand = -1
#   463: demand = -1
#   464: demand = -1
#   465: demand = -1
#   466: demand = -1
#   467: demand = -1
#   468: demand = -1
#   469: demand = -1
#   470: demand = -1
#   471: demand = -1
#   472: demand = -1
#   473: demand = -1
#   474: demand = -1
#   475: demand = -1
#   476: demand = -1
#   477: demand = -1
#   478: demand = -1
#   479: demand = -1
#   480: demand = -1
#   481: demand = -1
#   482: demand = -1
#   483: demand = -1
#   484: demand = -1
#   485: demand = -1
#   486: demand = -1
#   487: demand = -1
#   488: demand = -1
#   489: demand = -1
#   490: demand = -1
#   491: demand = -1
#   492: demand = -1
#   493: demand = -1
#   494: demand = -1
#   495: demand = -1
#   496: demand = -1
#   497: demand = -1
#   498: demand = -1
#   499: demand = -1
#   500: demand = -1
#   501: demand = -1
#   502: demand = -1
#   503: demand = -1
#   504: demand = -1
#   505: demand = -1
#   506: demand = -1
#   507: demand = -1
#   508: demand = -1
#   509: demand = -1
#   510: demand = -1
#   511: demand = -1
#   512: demand = -1
#   513: demand = -1
#   514: demand = -1
#   515: demand = -1
#   516: demand = -1
#   517: demand = -1
#   518: demand = -1
#   519: demand = -1
#   520: demand = -1
#   521: demand = -1
#   522: demand = -1
#   523: demand = -1
#   524: demand = -1
#   525: demand = -1
#   526: demand = -1
#   527: demand = -1
#   528: demand = -1
#   529: demand = -1
#   530: demand = -1
#   531: demand = -1
#   532: demand = -1
#   533: demand = -1
#   534: demand = -1
#   535: demand = -1
#   536: demand = -1
#   537: demand = -1
#   538: demand = -1
#   539: demand = -1
#   540: demand = -1
#   541: demand = -1
#   542: demand = -1
#   543: demand = -1
#   544: demand = -1
#   545: demand = -1
#   546: demand = -1
#   547: demand = -1
#   548: demand = -1
#   549: demand = -1
#   550: demand = -1
#   551: demand = -1
#   552: demand = -1
#   553: demand = -1
#   554: demand = -1
#   555: demand = -1
#   556: demand = -1
#   557: demand = -1
#   558: demand = -1
#   559: demand = -1
#   560: demand = -1
#   561: demand = -1
#   562: demand = -1
#   563: demand = -1
#   564: demand = -1
#   565: demand = -1
#   566: demand = -1
#   567: demand = -1
#   568: demand = -1
#   569: demand = -1
#   570: demand = -1
#   571: demand = -1
#   572: demand = -1
#   573: demand = -1
#   574: demand = -1
#   575: demand = -1
#   576: demand = -1
#   577: demand = -1
#   578: demand = -1
#   579: demand = -1
#   580: demand = -1
#   581: demand = -1
#   582: demand = -1
#   583: demand = -1
#   584: demand = -1
#   585: demand = -1
#   586: demand = -1
#   587: demand = -1
#   588: demand = -1
#   589: demand = -1
#   590: demand = -1
#   591: demand = -1
#   592: demand = -1
#   593: demand = -1
#   594: demand = -1
#   595: demand = -1
#   596: demand = -1
#   597: demand = -1
#   598: demand = -1
#   599: demand = -1
#   600: demand = -1
#   601: demand = -1
#   602: demand = -1
#   603: demand = -1
#   604: demand = -1
#   605: demand = -1
#   606: demand = -1
#   607: demand = -1
#   608: demand = -1
#   609: demand = -1
#   610: demand = -1
#   611: demand = -1
#   612: demand = -1
#   613: demand = -1
#   614: demand = -1
#   615: demand = -1
#   616: demand = -1
#   617: demand = -1
#   618: demand = -1
#   619: demand = -1
#   620: demand = -1
#   621: demand = -1
#   622: demand = -1
#   623: demand = -1
#   624: demand = -1
#   625: demand = -1
#   626: demand = -1
#   627: demand = -1
#   628: demand = -1
#   629: demand = -1
#   630: demand = -1
#   631: demand = -1
#   632: demand = -1
#   633: demand = -1
#   634: demand = -1
#   635: demand = -1
#   636: demand = -1
#   637: demand = -1
#   638: demand = -1
#   639: demand = -1
#   640: demand = -1
#   641: demand = -1
#   642: demand = -1
#   643: demand = -1
#   644: demand = -1
#   645: demand = -1
#   646: demand = -1
#   647: demand = -1
#   648: demand = -1
#   649: demand = -1
#   650: demand = -1
#   651: demand = -1
#   652: demand = -1
#   653: demand = -1
#   654: demand = -1
#   655: demand = -1
#   656: demand = -1
#   657: demand = -1
#   658: demand = -1
#   659: demand = -1
#   660: demand = -1
#   661: demand = -1
#   662: demand = -1
#   663: demand = -1
#   664: demand = -1
#   665: demand = -1
#   666: demand = -1
#   667: demand = -1
#   668: demand = -1
#   669: demand = -1
#   670: demand = -1
#   671: demand = -1
#   672: demand = -1
#   673: demand = -1
#   674: demand = -1
#   675: demand = -1
#   676: demand = -1
#   677: demand = -1
#   678: demand = -1
#   679: demand = -1
#   680: demand = -1
#   681: demand = -1
#   682: demand = -1
#   683: demand = -1
#   684: demand = -1
#   685: demand = -1
#   686: demand = -1
#   687: demand = -1
#   688: demand = -1
#   689: demand = -1
#   690: demand = -1
#   691: demand = -1
#   692: demand = -1
#   693: demand = -1
#   694: demand = -1
#   695: demand = -1
#   696: demand = -1
#   697: demand = -1
#   698: demand = -1
#   699: demand = -1
#   700: demand = -1
#   701: demand = -1
#   702: demand = -1
#   703: demand = -1
#   704: demand = -1
#   705: demand = -1
#   706: demand = -1
#   707: demand = -1
#   708: demand = -1
#   709: demand = -1
#   710: demand = -1
#   711: demand = -1
#   712: demand = -1
#   713: demand = -1
#   714: demand = -1
#   715: demand = -1
#   716: demand = -1
#   717: demand = -1
#   718: demand = -1
#   719: demand = -1
#   720: demand = -1
#   721: demand = -1
#   722: demand = -1
#   723: demand = -1
#   724: demand = -1
#   725: demand = -1
#   726: demand = -1
#   727: demand = -1
#   728: demand = -1
#   729: demand = -1
#   730: demand = -1
#   731: demand = -1
#   732: demand = -1
#   733: demand = -1
#   734: demand = -1
#   735: demand = -1
#   736: demand = -1
#   737: demand = -1
#   738: demand = -1
#   739: demand = -1
#   740: demand = -1
#   741: demand = -1
#   742: demand = -1
#   743: demand = -1
#   744: demand = -1
#   745: demand = -1
#   746: demand = -1
#   747: demand = -1
#   748: demand = -1
#   749: demand = -1
#   750: demand = -1
#   751: demand = -1
#   752: demand = -1
#   753: demand = -1
#   754: demand = -1
#   755: demand = -1
#   756: demand = -1
#   757: demand = -1
#   758: demand = -1
#   759: demand = -1
#   760: demand = -1
#   761: demand = -1
#   762: demand = -1
#   763: demand = -1
#   764: demand = -1
#   765: demand = -1
#   766: demand = -1
#   767: demand = -1
#   768: demand = -1
#   769: demand = -1
#   770: demand = -1
#   771: demand = -1
#   772: demand = -1
#   773: demand = -1
#   774: demand = -1
#   775: demand = -1
#   776: demand = -1
#   777: demand = -1
#   778: demand = -1
#   779: demand = -1
#   780: demand = -1
#   781: demand = -1
#   782: demand = -1
#   783: demand = -1
#   784: demand = -1
#   785: demand = -1
#   786: demand = -1
#   787: demand = -1
#   788: demand = -1
#   789: demand = -1
#   790: demand = -1
#   791: demand = -1
#   792: demand = -1
#   793: demand = -1
#   794: demand = -1
#   795: demand = -1
#   796: demand = -1
#   797: demand = -1
#   798: demand = -1
#   799: demand = -1
#   800: demand = -1
#   801: demand = -1
#   802: demand = -1
#   803: demand = -1
#   804: demand = -1
#   805: demand = -1
#   806: demand = -1
#   807: demand = -1
#   808: demand = -1
#   809: demand = -1
#   810: demand = -1
#   811: demand = -1
#   812: demand = -1
#   813: demand = -1
#   814: demand = -1
#   815: demand = -1
#   816: demand = -1
#   817: demand = -1
#   818: demand = -1
#   819: demand = -1
#   820: demand = -1
#   821: demand = -1
#   822: demand = -1
#   823: demand = -1
#   824: demand = -1
#   825: demand = -1
#   826: demand = -1
#   827: demand = -1
#   828: demand = -1
#   829: demand = -1
#   830: demand = -1
#   831: demand = -1
#   832: demand = -1
#   833: demand = -1
#   834: demand = -1
#   835: demand = -1
#   836: demand = -1
#   837: demand = -1
#   838: demand = -1
#   839: demand = -1
#   840: demand = -1
#   841: demand = -1
#   842: demand = -1
#   843: demand = -1
#   844: demand = -1
#   845: demand = -1
#   846: demand = -1
#   847: demand = -1
#   848: demand = -1
#   849: demand = -1
#   850: demand = -1
#   851: demand = -1
#   852: demand = -1
#   853: demand = -1
#   854: demand = -1
#   855: demand = -1
#   856: demand = -1
#   857: demand = -1
#   858: demand = -1
#   859: demand = -1
#   860: demand = -1
#   861: demand = -1
#   862: demand = -1
#   863: demand = -1
#   864: demand = -1
#   865: demand = -1
#   866: demand = -1
#   867: demand = -1
#   868: demand = -1
#   869: demand = -1
#   870: demand = -1
#   871: demand = -1
#   872: demand = -1
#   873: demand = -1
#   874: demand = -1
#   875: demand = -1
#   876: demand = -1
#   877: demand = -1
#   878: demand = -1
#   879: demand = -1
#   880: demand = -1
#   881: demand = -1
#   882: demand = -1
#   883: demand = -1
#   884: demand = -1
#   885: demand = -1
#   886: demand = -1
#   887: demand = -1
#   888: demand = -1
#   889: demand = -1
#   890: demand = -1
#   891: demand = -1
#   892: demand = -1
#   893: demand = -1
#   894: demand = -1
#   895: demand = -1
#   896: demand = -1
#   897: demand = -1
#   898: demand = -1
#   899: demand = -1
#   900: demand = -1
#   901: demand = -1
#   902: demand = -1
#   903: demand = -1
#   904: demand = -1
#   905: demand = -1
#   906: demand = -1
#   907: demand = -1
#   908: demand = -1
#   909: demand = -1
#   910: demand = -1
#   911: demand = -1
#   912: demand = -1
#   913: demand = -1
#   914: demand = -1
#   915: demand = -1
#   916: demand = -1
#   917: demand = -1
#   918: demand = -1
#   919: demand = -1
#   920: demand = -1
#   921: demand = -1
#   922: demand = -1
#   923: demand = -1
#   924: demand = -1
#   925: demand = -1
#   926: demand = -1
#   927: demand = -1
#   928: demand = -1
#   929: demand = -1
#   930: demand = -1
#   931: demand = -1
#   932: demand = -1
#   933: demand = -1
#   934: demand = -1
#   935: demand = -1
#   936: demand = -1
#   937: demand = -1
#   938: demand = -1
#   939: demand = -1
#   940: demand = -1
#   941: demand = -1
#   942: demand = -1
#   943: demand = -1
#   944: demand = -1
#   945: demand = -1
#   946: demand = -1
#   947: demand = -1
#   948: demand = -1
#   949: demand = -1
#   950: demand = -1
#   951: demand = -1
#   952: demand = -1
#   953: demand = -1
#   954: demand = -1
#   955: demand = -1
#   956: demand = -1
#   957: demand = -1
#   958: demand = -1
#   959: demand = -1
#   960: demand = -1
#   961: demand = -1
#   962: demand = -1
#   963: demand = -1
#   964: demand = -1
#   965: demand = -1
#   966: demand = -1
#   967: demand = -1
#   968: demand = -1
#   969: demand = -1
#   970: demand = -1
#   971: demand = -1
#   972: demand = -1
#   973: demand = -1
#   974: demand = -1
#   975: demand = -1
#   976: demand = -1
#   977: demand = -1
#   978: demand = -1
#   979: demand = -1
#   980: demand = -1
#   981: demand = -1
#   982: demand = -1
#   983: demand = -1
#   984: demand = -1
#   985: demand = -1
#   986: demand = -1
#   987: demand = -1
#   988: demand = -1
#   989: demand = -1
#   990: demand = -1
#   991: demand = -1
#   992: demand = -1
#   993: demand = -1
#   994: demand = -1
#   995: demand = -1
#   996: demand = -1
#   997: demand = -1
#   998: demand = -1
#   999: demand = -1
#   1000: demand = -1
#   1001: demand = -1
#   1002: demand = -1
#   1003: demand = -1
#   1004: demand = -1
#   1005: demand = -1
#   1006: demand = -1
#   1007: demand = -1
#   1008: demand = -1
#   1009: demand = -1
#   1010: demand = -1
#   1011: demand = -1
#   1012: demand = -1
#   1013: demand = -1
#   1014: demand = -1
#   1015: demand = -1
#   1016: demand = -1
#   1017: demand = -1
#   1018: demand = -1
#   1019: demand = -1
#   1020: demand = -1
#   1021: demand = -1
#   1022: demand = -1
#   1023: demand = -1
#   1024: demand = -1
#   1025: demand = -1
#   1026: demand = -1
#   1027: demand = -1
#   1028: demand = -1
#   1029: demand = -1
#   1030: demand = -1
#   1031: demand = -1
#   1032: demand = -1
#   1033: demand = -1
#   1034: demand = -1
#   1035: demand = -1
#   1036: demand = -1
#   1037: demand = -1
#   1038: demand = -1
#   1039: demand = -1
#   1040: demand = -1
#   1041: demand = -1
#   1042: demand = -1
#   1043: demand = -1
#   1044: demand = -1
#   1045: demand = -1
#   1046: demand = -1
#   1047: demand = -1
#   1048: demand = -1
#   1049: demand = -1
#   1050: demand = -1
#   1051: demand = -1
#   1052: demand = -1
#   1053: demand = -1
#   1054: demand = -1
#   1055: demand = -1
#   1056: demand = -1
#   1057: demand = -1
#   1058: demand = -1
#   1059: demand = -1
#   1060: demand = -1
#   1061: demand = -1
#   1062: demand = -1
#   1063: demand = -1
#   1064: demand = -1
#   1065: demand = -1
#   1066: demand = -1
#   1067: demand = -1
#   1068: demand = -1
#   1069: demand = -1
#   1070: demand = -1
#   1071: demand = -1
#   1072: demand = -1
#   1073: demand = -1
#   1074: demand = -1
#   1075: demand = -1
#   1076: demand = -1
#   1077: demand = -1
#   1078: demand = -1
#   1079: demand = -1
#   1080: demand = -1
#   1081: demand = -1
#   1082: demand = -1
#   1083: demand = -1
#   1084: demand = -1
#   1085: demand = -1
#   1086: demand = -1
#   1087: demand = -1
#   1088: demand = -1
#   1089: demand = -1
#   1090: demand = -1
#   1091: demand = -1
#   1092: demand = -1
#   1093: demand = -1
#   1094: demand = -1
#   1095: demand = -1
#   1096: demand = -1
#   1097: demand = -1
#   1098: demand = -1
#   1099: demand = -1
#   1100: demand = -1
#   1101: demand = -1
#   1102: demand = -1
#   1103: demand = -1
#   1104: demand = -1
#   1105: demand = -1
#   1106: demand = -1
#   1107: demand = -1
#   1108: demand = -1
#   1109: demand = -1
#   1110: demand = -1
#   1111: demand = -1
#   1112: demand = -1
#   1113: demand = -1
#   1114: demand = -1
#   1115: demand = -1
#   1116: demand = -1
#   1117: demand = -1
#   1118: demand = -1
#   1119: demand = -1
#   1120: demand = -1
#   1121: demand = -1
#   1122: demand = -1
#   1123: demand = -1
#   1124: demand = -1
#   1125: demand = -1
#   1126: demand = -1
#   1127: demand = -1
#   1128: demand = -1
#   1129: demand = -1
#   1130: demand = -1
#   1131: demand = -1
#   1132: demand = -1
#   1133: demand = -1
#   1134: demand = -1
#   1135: demand = -1
#   1136: demand = -1
#   1137: demand = -1
#   1138: demand = -1
#   1139: demand = -1
#   1140: demand = -1
#   1141: demand = -1
#   1142: demand = -1
#   1143: demand = -1
#   1144: demand = -1
#   1145: demand = -1
#   1146: demand = -1
#   1147: demand = -1
#   1148: demand = -1
#   1149: demand = -1
#   1150: demand = -1
#   1151: demand = -1
#   1152: demand = -1
#   1153: demand = -1
#   1154: demand = -1
#   1155: demand = -1
#   1156: demand = -1
#   1157: demand = -1
#   1158: demand = -1
#   1159: demand = -1
#   1160: demand = -1
#   1161: demand = -1
#   1162: demand = -1
#   1163: demand = -1
#   1164: demand = -1
#   1165: demand = -1
#   1166: demand = -1
#   1167: demand = -1
#   1168: demand = -1
#   1169: demand = -1
#   1170: demand = -1
#   1171: demand = -1
#   1172: demand = -1
#   1173: demand = -1
#   1174: demand = -1
#   1175: demand = -1
#   1176: demand = -1
#   1177: demand = -1
#   1178: demand = -1
#   1179: demand = -1
#   1180: demand = -1
#   1181: demand = -1
#   1182: demand = -1
#   1183: demand = -1
#   1184: demand = -1
#   1185: demand = -1
#   1186: demand = -1
#   1187: demand = -1
#   1188: demand = -1
#   1189: demand = -1
#   1190: demand = -1
#   1191: demand = -1
#   1192: demand = -1
#   1193: demand = -1
#   1194: demand = -1
#   1195: demand = -1
#   1196: demand = -1
#   1197: demand = -1
#   1198: demand = -1
#   1199: demand = -1
#   1200: demand = -1
#   1201: demand = -1
#   1202: demand = -1
#   1203: demand = -1
#   1204: demand = -1
#   1205: demand = -1
#   1206: demand = -1
#   1207: demand = -1
#   1208: demand = -1
#   1209: demand = -1
#   1210: demand = -1
#   1211: demand = -1
#   1212: demand = -1
#   1213: demand = -1
#   1214: demand = -1
#   1215: demand = -1
#   1216: demand = -1
#   1217: demand = -1
#   1218: demand = -1
#   1219: demand = -1
#   1220: demand = -1
#   1221: demand = -1
#   1222: demand = -1
#   1223: demand = -1
#   1224: demand = -1
#   1225: demand = -1
#   1226: demand = -1
#   1227: demand = -1
#   1228: demand = -1
#   1229: demand = -1
#   1230: demand = -1
#   1231: demand = -1
#   1232: demand = -1
#   1233: demand = -1
#   1234: demand = -1
#   1235: demand = -1
#   1236: demand = -1
#   1237: demand = -1
#   1238: demand = -1
#   1239: demand = -1
#   1240: demand = -1
#   1241: demand = -1
#   1242: demand = -1
#   1243: demand = -1
#   1244: demand = -1
#   1245: demand = -1
#   1246: demand = -1
#   1247: demand = -1
#   1248: demand = -1
#   1249: demand = -1
#   1250: demand = -1
#   1251: demand = -1
#   1252: demand = -1
#   1253: demand = -1
#   1254: demand = -1
#   1255: demand = -1
#   1256: demand = -1
#   1257: demand = -1
#   1258: demand = -1
#   1259: demand = -1
#   1260: demand = -1
#   1261: demand = -1
#   1262: demand = -1
#   1263: demand = -1
#   1264: demand = -1
#   1265: demand = -1
#   1266: demand = -1
#   1267: demand = -1
#   1268: demand = -1
#   1269: demand = -1
#   1270: demand = -1
#   1271: demand = -1
#   1272: demand = -1
#   1273: demand = -1
#   1274: demand = -1
#   1275: demand = -1
#   1276: demand = -1
#   1277: demand = -1
#   1278: demand = -1
#   1279: demand = -1
#   1280: demand = -1
#   1281: demand = -1
#   1282: demand = -1
#   1283: demand = -1
#   1284: demand = -1
#   1285: demand = -1
#   1286: demand = -1
#   1287: demand = -1
#   1288: demand = -1
#   1289: demand = -1
#   1290: demand = -1
#   1291: demand = -1
#   1292: demand = -1
#   1293: demand = -1
#   1294: demand = -1
#   1295: demand = -1
#   1296: demand = -1
#   1297: demand = -1
#   1298: demand = -1
#   1299: demand = -1
#   1300: demand = -1
#   1301: demand = -1
#   1302: demand = -1
#   1303: demand = -1
#   1304: demand = -1
#   1305: demand = -1
#   1306: demand = -1
#   1307: demand = -1
#   1308: demand = -1
#   1309: demand = -1
#   1310: demand = -1
#   1311: demand = -1
#   1312: demand = -1
#   1313: demand = -1
#   1314: demand = -1
#   1315: demand = -1
#   1316: demand = -1
#   1317: demand = -1
#   1318: demand = -1
#   1319: demand = -1
#   1320: demand = -1
#   1321: demand = -1
#   1322: demand = -1
#   1323: demand = -1
#   1324: demand = -1
#   1325: demand = -1
#   1326: demand = -1
#   1327: demand = -1
#   1328: demand = -1
#   1329: demand = -1
#   1330: demand = -1
#   1331: demand = -1
#   1332: demand = -1
#   1333: demand = -1
#   1334: demand = -1
#   1335: demand = -1
#   1336: demand = -1
#   1337: demand = -1
#   1338: demand = -1
#   1339: demand = -1
#   1340: demand = -1
#   1341: demand = -1
#   1342: demand = -1
#   1343: demand = -1
#   1344: demand = -1
#   1345: demand = -1
#   1346: demand = -1
#   1347: demand = -1
#   1348: demand = -1
#   1349: demand = -1
#   1350: demand = -1
#   1351: demand = -1
#   1352: demand = -1
#   1353: demand = -1
#   1354: demand = -1
#   1355: demand = -1
#   1356: demand = -1
#   1357: demand = -1
#   1358: demand = -1
#   1359: demand = -1
#   1360: demand = -1
#   1361: demand = -1
#   1362: demand = -1
#   1363: demand = -1
#   1364: demand = -1
#   1365: demand = -1
#   1366: demand = -1
#   1367: demand = -1
#   1368: demand = -1
#   1369: demand = -1
#   1370: demand = -1
#   1371: demand = -1
#   1372: demand = -1
#   1373: demand = -1
#   1374: demand = -1
#   1375: demand = -1
#   1376: demand = -1
#   1377: demand = -1
#   1378: demand = -1
#   1379: demand = -1
#   1380: demand = -1
#   1381: demand = -1
#   1382: demand = -1
#   1383: demand = -1
#   1384: demand = -1
#   1385: demand = -1
#   1386: demand = -1
#   1387: demand = -1
#   1388: demand = -1
#   1389: demand = -1
#   1390: demand = -1
#   1391: demand = -1
#   1392: demand = -1
#   1393: demand = -1
#   1394: demand = -1
#   1395: demand = -1
#   1396: demand = -1
#   1397: demand = -1
#   1398: demand = -1
#   1399: demand = -1
#   1400: demand = -1
#   1401: demand = -1
#   1402: demand = -1
#   1403: demand = -1
#   1404: demand = -1
#   1405: demand = -1
#   1406: demand = -1
#   1407: demand = -1
#   1408: demand = -1
#   1409: demand = -1
#   1410: demand = -1
#   1411: demand = -1
#   1412: demand = -1
#   1413: demand = -1
#   1414: demand = -1
#   1415: demand = -1
#   1416: demand = -1
#   1417: demand = -1
#   1418: demand = -1
#   1419: demand = -1
#   1420: demand = -1
#   1421: demand = -1
#   1422: demand = -1
#   1423: demand = -1
#   1424: demand = -1
#   1425: demand = -1
#   1426: demand = -1
#   1427: demand = -1
#   1428: demand = -1
#   1429: demand = -1
#   1430: demand = -1
#   1431: demand = -1
#   1432: demand = -1
#   1433: demand = -1
#   1434: demand = -1
#   1435: demand = -1
#   1436: demand = -1
#   1437: demand = -1
#   1438: demand = -1
#   1439: demand = -1
#   1440: demand = -1
#   1441: demand = -1
#   1442: demand = -1
#   1443: demand = -1
#   1444: demand = -1
#   1445: demand = -1
#   1446: demand = -1
#   1447: demand = -1
#   1448: demand = -1
#   1449: demand = -1
#   1450: demand = -1
#   1451: demand = -1
#   1452: demand = -1
#   1453: demand = -1
#   1454: demand = -1
#   1455: demand = -1
#   1456: demand = -1
#   1457: demand = -1
#   1458: demand = -1
#   1459: demand = -1
#   1460: demand = -1
#   1461: demand = -1
#   1462: demand = -1
#   1463: demand = -1
#   1464: demand = -1
#   1465: demand = -1
#   1466: demand = -1
#   1467: demand = -1
#   1468: demand = -1
#   1469: demand = -1
#   1470: demand = -1
#   1471: demand = -1
#   1472: demand = -1
#   1473: demand = -1
#   1474: demand = -1
#   1475: demand = -1
#   1476: demand = -1
#   1477: demand = -1
#   1478: demand = -1
#   1479: demand = -1
#   1480: demand = -1
#   1481: demand = -1
#   1482: demand = -1
#   1483: demand = -1
#   1484: demand = -1
#   1485: demand = -1
#   1486: demand = -1
#   1487: demand = -1
#   1488: demand = -1
#   1489: demand = -1
#   1490: demand = -1
#   1491: demand = -1
#   1492: demand = -1
#   1493: demand = -1
#   1494: demand = -1
#   1495: demand = -1
#   1496: demand = -1
#   1497: demand = -1
#   1498: demand = -1
#   1499: demand = -1
#   1500: demand = -1
#   1501: demand = -1
#   1502: demand = -1
#   1503: demand = -1
#   1504: demand = -1
#   1505: demand = -1
#   1506: demand = -1
#   1507: demand = -1
#   1508: demand = -1
#   1509: demand = -1
#   1510: demand = -1
#   1511: demand = -1
#   1512: demand = -1
#   1513: demand = -1
#   1514: demand = -1
#   1515: demand = -1
#   1516: demand = -1
#   1517: demand = -1
#   1518: demand = -1
#   1519: demand = -1
#   1520: demand = -1
#   1521: demand = -1
#   1522: demand = -1
#   1523: demand = -1
#   1524: demand = -1
#   1525: demand = -1
#   1526: demand = -1
#   1527: demand = -1
#   1528: demand = -1
#   1529: demand = -1
#   1530: demand = -1
#   1531: demand = -1
#   1532: demand = -1
#   1533: demand = -1
#   1534: demand = -1
#   1535: demand = -1
#   1536: demand = -1
#   1537: demand = -1
#   1538: demand = -1
#   1539: demand = -1
#   1540: demand = -1
#   1541: demand = -1
#   1542: demand = -1
#   1543: demand = -1
#   1544: demand = -1
#   1545: demand = -1
#   1546: demand = -1
#   1547: demand = -1
#   1548: demand = -1
#   1549: demand = -1
#   1550: demand = -1
#   1551: demand = -1
#   1552: demand = -1
#   1553: demand = -1
#   1554: demand = -1
#   1555: demand = -1
#   1556: demand = -1
#   1557: demand = -1
#   1558: demand = -1
#   1559: demand = -1
#   1560: demand = -1
#   1561: demand = -1
#   1562: demand = -1
#   1563: demand = -1
#   1564: demand = -1
#   1565: demand = -1
#   1566: demand = -1
#   1567: demand = -1
#   1568: demand = -1
#   1569: demand = -1
#   1570: demand = -1
#   1571: demand = -1
#   1572: demand = -1
#   1573: demand = -1
#   1574: demand = -1
#   1575: demand = -1
#   1576: demand = -1
#   1577: demand = -1
#   1578: demand = -1
#   1579: demand = -1
#   1580: demand = -1
#   1581: demand = -1
#   1582: demand = -1
#   1583: demand = -1
#   1584: demand = -1
#   1585: demand = -1
#   1586: demand = -1
#   1587: demand = -1
#   1588: demand = -1
#   1589: demand = -1
#   1590: demand = -1
#   1591: demand = -1
#   1592: demand = -1
#   1593: demand = -1
#   1594: demand = -1
#   1595: demand = -1
#   1596: demand = -1
#   1597: demand = -1
#   1598: demand = -1
#   1599: demand = -1
#   1600: demand = -1
#   1601: demand = -1
#   1602: demand = -1
#   1603: demand = -1
#   1604: demand = -1
#   1605: demand = -1
#   1606: demand = -1
#   1607: demand = -1
#   1608: demand = -1
#   1609: demand = -1
#   1610: demand = -1
#   1611: demand = -1
#   1612: demand = -1
#   1613: demand = -1
#   1614: demand = -1
#   1615: demand = -1
#   1616: demand = -1
#   1617: demand = -1
#   1618: demand = -1
#   1619: demand = -1
#   1620: demand = -1
#   1621: demand = -1
#   1622: demand = -1
#   1623: demand = -1
#   1624: demand = -1
#   1625: demand = -1
#   1626: demand = -1
#   1627: demand = -1
#   1628: demand = -1
#   1629: demand = -1
#   1630: demand = -1
#   1631: demand = -1
#   1632: demand = -1
#   1633: demand = -1
#   1634: demand = -1
#   1635: demand = -1
#   1636: demand = -1
#   1637: demand = -1
#   1638: demand = -1
#   1639: demand = -1
#   1640: demand = -1
#   1641: demand = -1
#   1642: demand = -1
#   1643: demand = -1
#   1644: demand = -1
#   1645: demand = -1
#   1646: demand = -1
#   1647: demand = -1
#   1648: demand = -1
#   1649: demand = -1
#   1650: demand = -1
#   1651: demand = -1
#   1652: demand = -1
#   1653: demand = -1
#   1654: demand = -1
#   1655: demand = -1
#   1656: demand = -1
#   1657: demand = -1
#   1658: demand = -1
#   1659: demand = -1
#   1660: demand = -1
#   1661: demand = -1
#   1662: demand = -1
#   1663: demand = -1
#   1664: demand = -1
#   1665: demand = -1
#   1666: demand = -1
#   1667: demand = -1
#   1668: demand = -1
#   1669: demand = -1
#   1670: demand = -1
#   1671: demand = -1
#   1672: demand = -1
#   1673: demand = -1
#   1674: demand = -1
#   1675: demand = -1
#   1676: demand = -1
#   1677: demand = -1
#   1678: demand = -1
#   1679: demand = -1
#   1680: demand = -1
#   1681: demand = -1
#   1682: demand = -1
#   1683: demand = -1
#   1684: demand = -1
#   1685: demand = -1
#   1686: demand = -1
#   1687: demand = -1
#   1688: demand = -1
#   1689: demand = -1
#   1690: demand = -1
#   1691: demand = -1
#   1692: demand = -1
#   1693: demand = -1
#   1694: demand = -1
#   1695: demand = -1
#   1696: demand = -1
#   1697: demand = -1
#   1698: demand = -1
#   1699: demand = -1
#   1700: demand = -1
#   1701: demand = -1
#   1702: demand = -1
#   1703: demand = -1
#   1704: demand = -1
#   1705: demand = -1
#   1706: demand = -1
#   1707: demand = -1
#   1708: demand = -1
#   1709: demand = -1
#   1710: demand = -1
#   1711: demand = -1
#   1712: demand = -1
#   1713: demand = -1
#   1714: demand = -1
#   1715: demand = -1
#   1716: demand = -1
#   1717: demand = -1
#   1718: demand = -1
#   1719: demand = -1
#   1720: demand = -1
#   1721: demand = -1
#   1722: demand = -1
#   1723: demand = -1
#   1724: demand = -1
#   1725: demand = -1
#   1726: demand = -1
#   1727: demand = -1
#   1728: demand = -1
#   1729: demand = -1
#   1730: demand = -1
#   1731: demand = -1
#   1732: demand = -1
#   1733: demand = -1
#   1734: demand = -1
#   1735: demand = -1
#   1736: demand = -1
#   1737: demand = -1
#   1738: demand = -1
#   1739: demand = -1
#   1740: demand = -1
#   1741: demand = -1
#   1742: demand = -1
#   1743: demand = -1
#   1744: demand = -1
#   1745: demand = -1
#   1746: demand = -1
#   1747: demand = -1
#   1748: demand = -1
#   1749: demand = -1
#   1750: demand = -1
#   1751: demand = -1
#   1752: demand = -1
#   1753: demand = -1
#   1754: demand = -1
#   1755: demand = -1
#   1756: demand = -1
#   1757: demand = -1
#   1758: demand = -1
#   1759: demand = -1
#   1760: demand = -1
#   1761: demand = -1
#   1762: demand = -1
#   1763: demand = -1
#   1764: demand = -1
#   1765: demand = -1
#   1766: demand = -1
#   1767: demand = -1
#   1768: demand = -1
#   1769: demand = -1
#   1770: demand = -1
#   1771: demand = -1
#   1772: demand = -1
#   1773: demand = -1
#   1774: demand = -1
#   1775: demand = -1
#   1776: demand = -1
#   1777: demand = -1
#   1778: demand = -1
#   1779: demand = -1
#   1780: demand = -1
#   1781: demand = -1
#   1782: demand = -1
#   1783: demand = -1
#   1784: demand = -1
#   1785: demand = -1
#   1786: demand = -1
#   1787: demand = -1
#   1788: demand = -1
#   1789: demand = -1
#   1790: demand = -1
#   1791: demand = -1
#   1792: demand = -1
#   1793: demand = -1
#   1794: demand = -1
#   1795: demand = -1
#   1796: demand = -1
#   1797: demand = -1
#   1798: demand = -1
#   1799: demand = -1
#   1800: demand = -1
#   1801: demand = -1
#   1802: demand = -1
#   1803: demand = -1
#   1804: demand = -1
#   1805: demand = -1
#   1806: demand = -1
#   1807: demand = -1
#   1808: demand = -1
#   1809: demand = -1
#   1810: demand = -1
#   1811: demand = -1
#   1812: demand = -1
#   1813: demand = -1
#   1814: demand = -1
#   1815: demand = -1
#   1816: demand = -1
#   1817: demand = -1
#   1818: demand = -1
#   1819: demand = -1
#   1820: demand = -1
#   1821: demand = -1
#   1822: demand = -1
#   1823: demand = -1
#   1824: demand = -1
#   1825: demand = -1
#   1826: demand = -1
#   1827: demand = -1
#   1828: demand = -1
#   1829: demand = -1
#   1830: demand = -1
#   1831: demand = -1
#   1832: demand = -1
#   1833: demand = -1
#   1834: demand = -1
#   1835: demand = -1
#   1836: demand = -1
#   1837: demand = -1
#   1838: demand = -1
#   1839: demand = -1
#   1840: demand = -1
#   1841: demand = -1
#   1842: demand = -1
#   1843: demand = -1
#   1844: demand = -1
#   1845: demand = -1
#   1846: demand = -1
#   1847: demand = -1
#   1848: demand = -1
#   1849: demand = -1
#   1850: demand = -1
#   1851: demand = -1
#   1852: demand = -1
#   1853: demand = -1
#   1854: demand = -1
#   1855: demand = -1
#   1856: demand = -1
#   1857: demand = -1
#   1858: demand = -1
#   1859: demand = -1
#   1860: demand = -1
#   1861: demand = -1
#   1862: demand = -1
#   1863: demand = -1
#   1864: demand = -1
#   1865: demand = -1
#   1866: demand = -1
#   1867: demand = -1
#   1868: demand = -1
#   1869: demand = -1
#   1870: demand = -1
#   1871: demand = -1
#   1872: demand = -1
#   1873: demand = -1
#   1874: demand = -1
#   1875: demand = -1
#   1876: demand = -1
#   1877: demand = -1
#   1878: demand = -1
#   1879: demand = -1
#   1880: demand = -1
#   1881: demand = -1
#   1882: demand = -1
#   1883: demand = -1
#   1884: demand = -1
#   1885: demand = -1
#   1886: demand = -1
#   1887: demand = -1
#   1888: demand = -1
#   1889: demand = -1
#   1890: demand = -1
#   1891: demand = -1
#   1892: demand = -1
#   1893: demand = -1
#   1894: demand = -1
#   1895: demand = -1
#   1896: demand = -1
#   1897: demand = -1
#   1898: demand = -1
#   1899: demand = -1
#   1900: demand = -1
#   1901: demand = -1
#   1902: demand = -1
#   1903: demand = -1
#   1904: demand = -1
#   1905: demand = -1
#   1906: demand = -1
#   1907: demand = -1
#   1908: demand = -1
#   1909: demand = -1
#   1910: demand = -1
#   1911: demand = -1
#   1912: demand = -1
#   1913: demand = -1
#   1914: demand = -1
#   1915: demand = -1
#   1916: demand = -1
#   1917: demand = -1
#   1918: demand = -1
#   1919: demand = -1
#   1920: demand = -1
#   1921: demand = -1
#   1922: demand = -1
#   1923: demand = -1
#   1924: demand = -1
#   1925: demand = -1
#   1926: demand = -1
#   1927: demand = -1
#   1928: demand = -1
#   1929: demand = -1
#   1930: demand = -1
#   1931: demand = -1
#   1932: demand = -1
#   1933: demand = -1
#   1934: demand = -1
#   1935: demand = -1
#   1936: demand = -1
#   1937: demand = -1
#   1938: demand = -1
#   1939: demand = -1
#   1940: demand = -1
#   1941: demand = -1
#   1942: demand = -1
#   1943: demand = -1
#   1944: demand = -1
#   1945: demand = -1
#   1946: demand = -1
#   1947: demand = -1
#   1948: demand = -1
#   1949: demand = -1
#   1950: demand = -1
#   1951: demand = -1
#   1952: demand = -1
#   1953: demand = -1
#   1954: demand = -1
#   1955: demand = -1
#   1956: demand = -1
#   1957: demand = -1
#   1958: demand = -1
#   1959: demand = -1
#   1960: demand = -1
#   1961: demand = -1
#   1962: demand = -1
#   1963: demand = -1
#   1964: demand = -1
#   1965: demand = -1
#   1966: demand = -1
#   1967: demand = -1
#   1968: demand = -1
#   1969: demand = -1
#   1970: demand = -1
#   1971: demand = -1
#   1972: demand = -1
#   1973: demand = -1
#   1974: demand = -1
#   1975: demand = -1
#   1976: demand = -1
#   1977: demand = -1
#   1978: demand = -1
#   1979: demand = -1
#   1980: demand = -1
#   1981: demand = -1
#   1982: demand = -1
#   1983: demand = -1
#   1984: demand = -1
#   1985: demand = -1
#   1986: demand = -1
#   1987: demand = -1
#   1988: demand = -1
#   1989: demand = -1
#   1990: demand = -1
#   1991: demand = -1
#   1992: demand = -1
#   1993: demand = -1
#   1994: demand = -1
#   1995: demand = -1
#   1996: demand = -1
#   1997: demand = -1
#   1998: demand = -1
#   1999: demand = -1
#   2000: demand = -1
#   2001: demand = -1
#   2002: demand = -1
#   2003: demand = -1
#   2004: demand = -1
#   2005: demand = -1
#   2006: demand = -1
#   2007: demand = -1
#   2008: demand = -1
#   2009: demand = -1
#   2010: demand = -1
#   2011: demand = -1
#   2012: demand = -1
#   2013: demand = -1
#   2014: demand = -1
#   2015: demand = -1
#   2016: demand = -1
#   2017: demand = -1
#   2018: demand = -1
#   2019: demand = -1
#   2020: demand = -1
#   2021: demand = -1
#   2022: demand = -1
#   2023: demand = -1
#   2024: demand = -1
#   2025: demand = -1
#   2026: demand = -1
#   2027: demand = -1
#   2028: demand = -1
#   2029: demand = -1
#   2030: demand = -1
#   2031: demand = -1
#   2032: demand = -1
#   2033: demand = -1
#   2034: demand = -1
#   2035: demand = -1
#   2036: demand = -1
#   2037: demand = -1
#   2038: demand = -1
#   2039: demand = -1
#   2040: demand = -1
#   2041: demand = -1
#   2042: demand = -1
#   2043: demand = -1
#   2044: demand = -1
#   2045: demand = -1
#   2046: demand = -1
#   2047: demand = -1
#   2048: demand = -1
#   2049: demand = -1
#   2050: demand = -1
#   2051: demand = -1
#   2052: demand = -1
#   2053: demand = -1
#   2054: demand = -1
#   2055: demand = -1
#   2056: demand = -1
#   2057: demand = -1
#   2058: demand = -1
#   2059: demand = -1
#   2060: demand = -1
#   2061: demand = -1
#   2062: demand = -1
#   2063: demand = -1
#   2064: demand = -1
#   2065: demand = -1
#   2066: demand = -1
#   2067: demand = -1
#   2068: demand = -1
#   2069: demand = -1
#   2070: demand = -1
#   2071: demand = -1
#   2072: demand = -1
#   2073: demand = -1
#   2074: demand = -1
#   2075: demand = -1
#   2076: demand = -1
#   2077: demand = -1
#   2078: demand = -1
#   2079: demand = -1
#   2080: demand = -1
#   2081: demand = -1
#   2082: demand = -1
#   2083: demand = -1
#   2084: demand = -1
#   2085: demand = -1
#   2086: demand = -1
#   2087: demand = -1
#   2088: demand = -1
#   2089: demand = -1
#   2090: demand = -1
#   2091: demand = -1
#   2092: demand = -1
#   2093: demand = -1
#   2094: demand = -1
#   2095: demand = -1
#   2096: demand = -1
#   2097: demand = -1
#   2098: demand = -1
#   2099: demand = -1
#   2100: demand = -1
#   2101: demand = -1
#   2102: demand = -1
#   2103: demand = -1
#   2104: demand = -1
#   2105: demand = -1
#   2106: demand = -1
#   2107: demand = -1
#   2108: demand = -1
#   2109: demand = -1
#   2110: demand = -1
#   2111: demand = -1
#   2112: demand = -1
#   2113: demand = -1
#   2114: demand = -1
#   2115: demand = -1
#   2116: demand = -1
#   2117: demand = -1
#   2118: demand = -1
#   2119: demand = -1
#   2120: demand = -1
#   2121: demand = -1
#   2122: demand = -1
#   2123: demand = -1
#   2124: demand = -1
#   2125: demand = -1
#   2126: demand = -1
#   2127: demand = -1
#   2128: demand = -1
#   2129: demand = -1
#   2130: demand = -1
#   2131: demand = -1
#   2132: demand = -1
#   2133: demand = -1
#   2134: demand = -1
#   2135: demand = -1
#   2136: demand = -1
#   2137: demand = -1
#   2138: demand = -1
#   2139: demand = -1
#   2140: demand = -1
#   2141: demand = -1
#   2142: demand = -1
#   2143: demand = -1
#   2144: demand = -1
#   2145: demand = -1
#   2146: demand = -1
#   2147: demand = -1
#   2148: demand = -1
#   2149: demand = -1
#   2150: demand = -1
#   2151: demand = -1
#   2152: demand = -1
#   2153: demand = -1
#   2154: demand = -1
#   2155: demand = -1
#   2156: demand = -1
#   2157: demand = -1
#   2158: demand = -1
#   2159: demand = -1
#   2160: demand = -1
#   2161: demand = -1
#   2162: demand = -1
#   2163: demand = -1
#   2164: demand = -1
#   2165: demand = -1
#   2166: demand = -1
#   2167: demand = -1
#   2168: demand = -1
#   2169: demand = -1
#   2170: demand = -1
#   2171: demand = -1
#   2172: demand = -1
#   2173: demand = -1
#   2174: demand = -1
#   2175: demand = -1
#   2176: demand = -1
#   2177: demand = -1
#   2178: demand = -1
#   2179: demand = -1
#   2180: demand = -1
#   2181: demand = -1
#   2182: demand = -1
#   2183: demand = -1
#   2184: demand = -1
#   2185: demand = -1
#   2186: demand = -1
#   2187: demand = -1
#   2188: demand = -1
#   2189: demand = -1
#   2190: demand = -1
#   2191: demand = -1
#   2192: demand = -1
#   2193: demand = -1
#   2194: demand = -1
#   2195: demand = -1
#   2196: demand = -1
#   2197: demand = -1
#   2198: demand = -1
#   2199: demand = -1
#   2200: demand = -1
#   2201: demand = -1
#   2202: demand = -1
#   2203: demand = -1
#   2204: demand = -1
#   2205: demand = -1
#   2206: demand = -1
#   2207: demand = -1
#   2208: demand = -1
#   2209: demand = -1
#   2210: demand = -1
#   2211: demand = -1
#   2212: demand = -1
#   2213: demand = -1
#   2214: demand = -1
#   2215: demand = -1
#   2216: demand = -1
#   2217: demand = -1
#   2218: demand = -1
#   2219: demand = -1
#   2220: demand = -1
#   2221: demand = -1
#   2222: demand = -1
#   2223: demand = -1
#   2224: demand = -1
#   2225: demand = -1
#   2226: demand = -1
#   2227: demand = -1
#   2228: demand = -1
#   2229: demand = -1
#   2230: demand = -1
#   2231: demand = -1
#   2232: demand = -1
#   2233: demand = -1
#   2234: demand = -1
#   2235: demand = -1
#   2236: demand = -1
#   2237: demand = -1
#   2238: demand = -1
#   2239: demand = -1
#   2240: demand = -1
#   2241: demand = -1
#   2242: demand = -1
#   2243: demand = -1
#   2244: demand = -1
#   2245: demand = -1
#   2246: demand = -1
#   2247: demand = -1
#   2248: demand = -1
#   2249: demand = -1
#   2250: demand = -1
#   2251: demand = -1
#   2252: demand = -1
#   2253: demand = -1
#   2254: demand = -1
#   2255: demand = -1
#   2256: demand = -1
#   2257: demand = -1
#   2258: demand = -1
#   2259: demand = -1
#   2260: demand = -1
#   2261: demand = -1
#   2262: demand = -1
#   2263: demand = -1
#   2264: demand = -1
#   2265: demand = -1
#   2266: demand = -1
#   2267: demand = -1
#   2268: demand = -1
#   2269: demand = -1
#   2270: demand = -1
#   2271: demand = -1
#   2272: demand = -1
#   2273: demand = -1
#   2274: demand = -1
#   2275: demand = -1
#   2276: demand = -1
#   2277: demand = -1
#   2278: demand = -1
#   2279: demand = -1
#   2280: demand = -1
#   2281: demand = -1
#   2282: demand = -1
#   2283: demand = -1
#   2284: demand = -1
#   2285: demand = -1
#   2286: demand = -1
#   2287: demand = -1
#   2288: demand = -1
#   2289: demand = -1
#   2290: demand = -1
#   2291: demand = -1
#   2292: demand = -1
#   2293: demand = -1
#   2294: demand = -1
#   2295: demand = -1
#   2296: demand = -1
#   2297: demand = -1
#   2298: demand = -1
#   2299: demand = -1
#   2300: demand = -1
#   2301: demand = -1
#   2302: demand = -1
#   2303: demand = -1
#   2304: demand = -1
#   2305: demand = -1
#   2306: demand = -1
#   2307: demand = -1
#   2308: demand = -1
#   2309: demand = -1
#   2310: demand = -1
#   2311: demand = -1
#   2312: demand = -1
#   2313: demand = -1
#   2314: demand = -1
# ...
#   44672: demand = -1
#   44673: demand = -1
#   44674: demand = -1
#   44675: demand = -1
#   44676: demand = -1
#   44677: demand = -1
#   44678: demand = -1
#   44679: demand = -1
#   44680: demand = -1
#   44681: demand = -1
#   44682: demand = -1
#   44683: demand = -1
#   44684: demand = -1
#   44685: demand = -1
#   44686: demand = -1
#   44687: demand = -1
#   44688: demand = -1
#   44689: demand = -1
#   44690: demand = -1
#   44691: demand = -1
#   44692: demand = -1
#   44693: demand = -1
#   44694: demand = -1
#   44695: demand = -1
#   44696: demand = -1
#   44697: demand = -1
#   44698: demand = -1
#   44699: demand = -1
#   44700: demand = -1
#   44701: demand = -1
#   44702: demand = -1
#   44703: demand = -1
#   44704: demand = -1
#   44705: demand = -1
#   44706: demand = -1
#   44707: demand = -1
#   44708: demand = -1
#   44709: demand = -1
#   44710: demand = -1
#   44711: demand = -1
#   44712: demand = -1
#   44713: demand = -1
#   44714: demand = -1
#   44715: demand = -1
#   44716: demand = -1
#   44717: demand = -1
#   44718: demand = -1
#   44719: demand = -1
#   44720: demand = -1
#   44721: demand = -1
#   44722: demand = -1
#   44723: demand = -1
#   44724: demand = -1
#   44725: demand = -1
#   44726: demand = -1
#   44727: demand = -1
#   44728: demand = -1
#   44729: demand = -1
#   44730: demand = -1
#   44731: demand = -1
#   44732: demand = -1
#   44733: demand = -1
#   44734: demand = -1
#   44735: demand = -1
#   44736: demand = -1
#   44737: demand = -1
#   44738: demand = -1
#   44739: demand = -1
#   44740: demand = -1
#   44741: demand = -1
#   44742: demand = -1
#   44743: demand = -1
#   44744: demand = -1
#   44745: demand = -1
#   44746: demand = -1
#   44747: demand = -1
#   44748: demand = -1
#   44749: demand = -1
#   44750: demand = -1
#   44751: demand = -1
#   44752: demand = -1
#   44753: demand = -1
#   44754: demand = -1
#   44755: demand = -1
#   44756: demand = -1
#   44757: demand = -1
#   44758: demand = -1
#   44759: demand = -1
#   44760: demand = -1
#   44761: demand = -1
#   44762: demand = -1
#   44763: demand = -1
#   44764: demand = -1
#   44765: demand = -1
#   44766: demand = -1
#   44767: demand = -1
#   44768: demand = -1
#   44769: demand = -1
#   44770: demand = -1
#   44771: demand = -1
#   44772: demand = -1
#   44773: demand = -1
#   44774: demand = -1
#   44775: demand = -1
#   44776: demand = -1
#   44777: demand = -1
#   44778: demand = -1
#   44779: demand = -1
#   44780: demand = -1
#   44781: demand = -1
#   44782: demand = -1
#   44783: demand = -1
#   44784: demand = -1
#   44785: demand = -1
#   44786: demand = -1
#   44787: demand = -1
#   44788: demand = -1
#   44789: demand = -1
#   44790: demand = -1
#   44791: demand = -1
#   44792: demand = -1
#   44793: demand = -1
#   44794: demand = -1
#   44795: demand = -1
#   44796: demand = -1
#   44797: demand = -1
#   44798: demand = -1
#   44799: demand = -1
#   44800: demand = -1
#   44801: demand = -1
#   44802: demand = -1
#   44803: demand = -1
#   44804: demand = -1
#   44805: demand = -1
#   44806: demand = -1
#   44807: demand = -1
#   44808: demand = -1
#   44809: demand = -1
#   44810: demand = -1
#   44811: demand = -1
#   44812: demand = -1
#   44813: demand = -1
#   44814: demand = -1
#   44815: demand = -1
#   44816: demand = -1
#   44817: demand = -1
#   44818: demand = -1
#   44819: demand = -1
#   44820: demand = -1
#   44821: demand = -1
#   44822: demand = -1
#   44823: demand = -1
#   44824: demand = -1
#   44825: demand = -1
#   44826: demand = -1
#   44827: demand = -1
#   44828: demand = -1
#   44829: demand = -1
#   44830: demand = -1
#   44831: demand = -1
#   44832: demand = -1
#   44833: demand = -1
#   44834: demand = -1
#   44835: demand = -1
#   44836: demand = -1
#   44837: demand = -1
#   44838: demand = -1
#   44839: demand = -1
#   44840: demand = -1
#   44841: demand = -1
#   44842: demand = -1
#   44843: demand = -1
#   44844: demand = -1
#   44845: demand = -1
#   44846: demand = -1
#   44847: demand = -1
#   44848: demand = -1
#   44849: demand = -1
#   44850: demand = -1
#   44851: demand = -1
#   44852: demand = -1
#   44853: demand = -1
#   44854: demand = -1
#   44855: demand = -1
#   44856: demand = -1
#   44857: demand = -1
#   44858: demand = -1
#   44859: demand = -1
#   44860: demand = -1
#   44861: demand = -1
#   44862: demand = -1
#   44863: demand = -1
#   44864: demand = -1
#   44865: demand = -1
#   44866: demand = -1
#   44867: demand = -1
#   44868: demand = -1
#   44869: demand = -1
#   44870: demand = -1
#   44871: demand = -1
#   44872: demand = -1
#   44873: demand = -1
#   44874: demand = -1
#   44875: demand = -1
#   44876: demand = -1
#   44877: demand = -1
#   44878: demand = -1
#   44879: demand = -1
#   44880: demand = -1
#   44881: demand = -1
#   44882: demand = -1
#   44883: demand = -1
#   44884: demand = -1
#   44885: demand = -1
#   44886: demand = -1
#   44887: demand = -1
#   44888: demand = -1
#   44889: demand = -1
#   44890: demand = -1
#   44891: demand = -1
#   44892: demand = -1
#   44893: demand = -1
#   44894: demand = -1
#   44895: demand = -1
#   44896: demand = -1
#   44897: demand = -1
#   44898: demand = -1
#   44899: demand = -1
#   44900: demand = -1
#   44901: demand = -1
#   44902: demand = -1
#   44903: demand = -1
#   44904: demand = -1
#   44905: demand = -1
#   44906: demand = -1
#   44907: demand = -1
#   44908: demand = -1
#   44909: demand = -1
#   44910: demand = -1
#   44911: demand = -1
#   44912: demand = -1
#   44913: demand = -1
#   44914: demand = -1
#   44915: demand = -1
#   44916: demand = -1
#   44917: demand = -1
#   44918: demand = -1
#   44919: demand = -1
#   44920: demand = -1
#   44921: demand = -1
#   44922: demand = -1
#   44923: demand = -1
#   44924: demand = -1
#   44925: demand = -1
#   44926: demand = -1
#   44927: demand = -1
#   44928: demand = -1
#   44929: demand = -1
#   44930: demand = -1
#   44931: demand = -1
#   44932: demand = -1
#   44933: demand = -1
#   44934: demand = -1
#   44935: demand = -1
#   44936: demand = -1
#   44937: demand = -1
#   44938: demand = -1
#   44939: demand = -1
#   44940: demand = -1
#   44941: demand = -1
#   44942: demand = -1
#   44943: demand = -1
#   44944: demand = -1
#   44945: demand = -1
#   44946: demand = -1
#   44947: demand = -1
#   44948: demand = -1
#   44949: demand = -1
#   44950: demand = -1
#   44951: demand = -1
#   44952: demand = -1
#   44953: demand = -1
#   44954: demand = -1
#   44955: demand = -1
#   44956: demand = -1
#   44957: demand = -1
#   44958: demand = -1
#   44959: demand = -1
#   44960: demand = -1
#   44961: demand = -1
#   44962: demand = -1
#   44963: demand = -1
#   44964: demand = -1
#   44965: demand = -1
#   44966: demand = -1
#   44967: demand = -1
#   44968: demand = -1
#   44969: demand = -1
#   44970: demand = -1
#   44971: demand = -1
#   44972: demand = -1
#   44973: demand = -1
#   44974: demand = -1
#   44975: demand = -1
#   44976: demand = -1
#   44977: demand = -1
#   44978: demand = -1
#   44979: demand = -1
#   44980: demand = -1
#   44981: demand = -1
#   44982: demand = -1
#   44983: demand = -1
#   44984: demand = -1
#   44985: demand = -1
#   44986: demand = -1
#   44987: demand = -1
#   44988: demand = -1
#   44989: demand = -1
#   44990: demand = -1
#   44991: demand = -1
#   44992: demand = -1
#   44993: demand = -1
#   44994: demand = -1
#   44995: demand = -1
#   44996: demand = -1
#   44997: demand = -1
#   44998: demand = -1
#   44999: demand = -1
#   45000: demand = -1
#   45001: demand = -1
#   45002: demand = -1
#   45003: demand = -1
#   45004: demand = -1
#   45005: demand = -1
#   45006: demand = -1
#   45007: demand = -1
#   45008: demand = -1
#   45009: demand = -1
#   45010: demand = -1
#   45011: demand = -1
#   45012: demand = -1
#   45013: demand = -1
#   45014: demand = -1
#   45015: demand = -1
#   45016: demand = -1
#   45017: demand = -1
#   45018: demand = -1
#   45019: demand = -1
#   45020: demand = -1
#   45021: demand = -1
#   45022: demand = -1
#   45023: demand = -1
#   45024: demand = -1
#   45025: demand = -1
#   45026: demand = -1
#   45027: demand = -1
#   45028: demand = -1
#   45029: demand = -1
#   45030: demand = -1
#   45031: demand = -1
#   45032: demand = -1
#   45033: demand = -1
#   45034: demand = -1
#   45035: demand = -1
#   45036: demand = -1
#   45037: demand = -1
#   45038: demand = -1
#   45039: demand = -1
#   45040: demand = -1
#   45041: demand = -1
#   45042: demand = -1
#   45043: demand = -1
#   45044: demand = -1
#   45045: demand = -1
#   45046: demand = -1
#   45047: demand = -1
#   45048: demand = -1
#   45049: demand = -1
#   45050: demand = -1
#   45051: demand = -1
#   45052: demand = -1
#   45053: demand = -1
#   45054: demand = -1
#   45055: demand = -1
#   45056: demand = -1
#   45057: demand = -1
#   45058: demand = -1
#   45059: demand = -1
#   45060: demand = -1
#   45061: demand = -1
#   45062: demand = -1
#   45063: demand = -1
#   45064: demand = -1
#   45065: demand = -1
#   45066: demand = -1
#   45067: demand = -1
#   45068: demand = -1
#   45069: demand = -1
#   45070: demand = -1
#   45071: demand = -1
#   45072: demand = -1
#   45073: demand = -1
#   45074: demand = -1
#   45075: demand = -1
#   45076: demand = -1
#   45077: demand = -1
#   45078: demand = -1
#   45079: demand = -1
#   45080: demand = -1
#   45081: demand = -1
#   45082: demand = -1
#   45083: demand = -1
#   45084: demand = -1
#   45085: demand = -1
#   45086: demand = -1
#   45087: demand = -1
#   45088: demand = -1
#   45089: demand = -1
#   45090: demand = -1
#   45091: demand = -1
#   45092: demand = -1
#   45093: demand = -1
#   45094: demand = -1
#   45095: demand = -1
#   45096: demand = -1
#   45097: demand = -1
#   45098: demand = -1
#   45099: demand = -1
#   45100: demand = -1
#   45101: demand = -1
#   45102: demand = -1
#   45103: demand = -1
#   45104: demand = -1
#   45105: demand = -1
#   45106: demand = -1
#   45107: demand = -1
#   45108: demand = -1
#   45109: demand = -1
#   45110: demand = -1
#   45111: demand = -1
#   45112: demand = -1
#   45113: demand = -1
#   45114: demand = -1
#   45115: demand = -1
#   45116: demand = -1
#   45117: demand = -1
#   45118: demand = -1
#   45119: demand = -1
#   45120: demand = -1
#   45121: demand = -1
#   45122: demand = -1
#   45123: demand = -1
#   45124: demand = -1
#   45125: demand = -1
#   45126: demand = -1
#   45127: demand = -1
#   45128: demand = -1
#   45129: demand = -1
#   45130: demand = -1
#   45131: demand = -1
#   45132: demand = -1
#   45133: demand = -1
#   45134: demand = -1
#   45135: demand = -1
#   45136: demand = -1
#   45137: demand = -1
#   45138: demand = -1
#   45139: demand = -1
#   45140: demand = -1
#   45141: demand = -1
#   45142: demand = -1
#   45143: demand = -1
#   45144: demand = -1
#   45145: demand = -1
#   45146: demand = -1
#   45147: demand = -1
#   45148: demand = -1
#   45149: demand = -1
#   45150: demand = -1
#   45151: demand = -1
#   45152: demand = -1
#   45153: demand = -1
#   45154: demand = -1
#   45155: demand = -1
#   45156: demand = -1
#   45157: demand = -1
#   45158: demand = -1
#   45159: demand = -1
#   45160: demand = -1
#   45161: demand = -1
#   45162: demand = -1
#   45163: demand = -1
#   45164: demand = -1
#   45165: demand = -1
#   45166: demand = -1
#   45167: demand = -1
#   45168: demand = -1
#   45169: demand = -1
#   45170: demand = -1
#   45171: demand = -1
#   45172: demand = -1
#   45173: demand = -1
#   45174: demand = -1
#   45175: demand = -1
#   45176: demand = -1
#   45177: demand = -1
#   45178: demand = -1
#   45179: demand = -1
#   45180: demand = -1
#   45181: demand = -1
#   45182: demand = -1
#   45183: demand = -1
#   45184: demand = -1
#   45185: demand = -1
#   45186: demand = -1
#   45187: demand = -1
#   45188: demand = -1
#   45189: demand = -1
#   45190: demand = -1
#   45191: demand = -1
#   45192: demand = -1
#   45193: demand = -1
#   45194: demand = -1
#   45195: demand = -1
#   45196: demand = -1
#   45197: demand = -1
#   45198: demand = -1
#   45199: demand = -1
#   45200: demand = -1
#   45201: demand = -1
#   45202: demand = -1
#   45203: demand = -1
#   45204: demand = -1
#   45205: demand = -1
#   45206: demand = -1
#   45207: demand = -1
#   45208: demand = -1
#   45209: demand = -1
#   45210: demand = -1
#   45211: demand = -1
#   45212: demand = -1
#   45213: demand = -1
#   45214: demand = -1
#   45215: demand = -1
#   45216: demand = -1
#   45217: demand = -1
#   45218: demand = -1
#   45219: demand = -1
#   45220: demand = -1
#   45221: demand = -1
#   c10: demand = 1740
#   c11: demand = 750
#   c12: demand = 4656
#   c13: demand = 3634
#   c14: demand = 471
#   c15: demand = 305
#   c16: demand = 1104
#   c17: demand = 520
#   c18: demand = 734
#   c19: demand = 781
#   s0: demand = 2055
#   s1: demand = 11450
#   s2: demand = 4749
#   s3: demand = 1214
#   s4: demand = 2250
#   s5: demand = 1324
#   s6: demand = 3006
#   s7: demand = 956
#   s8: demand = 2442
#   s9: demand = 1080
#   t: demand = 1
# ---------------------------------------------------------------------------
# NetworkXUnfeasible                        Traceback (most recent call last)
# Cell In[4], line 2
#       1 centers = socially_fair_kmeans(data_normalized, svar_all, k=10)
# ----> 2 result = test_lp_and_rounding(data_normalized, svar_all, centers)
#
# Cell In[2], line 42, in test_lp_and_rounding(data_normalized, svar_all, centers, alpha_val, beta_val, lambda_param)
#      40 print("Calling rounding_wrapper...")
#      41 # Step 4: Run rounding
# ---> 42 result = rounding_wrapper(
#      43 lp_assignment=lp_result["x_frac"],
#      44 distance_matrix=distance_matrix,
#      45 color_labels=svar_all.to_numpy(),
#      46 num_clusters=centers.shape[0],
#      47 num_colors=len(unique_groups),
#      48 lp_objective=lp_result["z"],
#      49 df=data_normalized,
#      50 centers=centers
#      51 )
#      53 print("Rounding done!")
#      55 # Step 5: Print result summary
#
# File ~/FCBC_code/Welfare_Clustering/min_cost_rounding.py:296, in rounding_wrapper(lp_assignment, distance_matrix, color_labels, num_clusters, num_colors, lp_objective, df, centers, epsilon)
#     290 res = {
#     291     "partial_assignment": lp_assignment,
#     292     "partial_objective": lp_objective,
#     293 }
#     295 # Step 2: Call min-cost rounding using data and centers
# --> 296 x_rounded = min_cost_rounding_multi_color(
#     297 df,
#     298 centers,
#     299 distance_matrix,
#     300 color_labels,
#     301 num_colors,
#     302 res
#     303 )
#     306 print(">>> Got x_rounded back")
#     308 # Step 3: Validate hard clustering
#
# File ~/FCBC_code/Welfare_Clustering/min_cost_rounding.py:219, in min_cost_rounding_multi_color(df, centers, distance, color_flag, num_colors, res)
#     215         print(f"  {node}: demand = {d}")
#     218 # Step 7: Solve the network flow problem
# --> 219 flowCost, flowDict = nx.network_simplex(G)
#     222 # Step 8: convert solution to assignments x
#     223 x_rounded = np.zeros((n,num_clusters))
#
# File ~/Documents/welfare_clustering/cplex-env/lib/python3.10/site-packages/networkx/utils/decorators.py:788, in argmap.__call__.<locals>.func(_argmap__wrapper, *args, **kwargs)
#     787 def func(*args, __wrapper=None, **kwargs):
# --> 788     return argmap._lazy_compile(__wrapper)(*args, **kwargs)
#
# File <class 'networkx.utils.decorators.argmap'> compilation 5:4, in argmap_network_simplex_1(G, demand, capacity, weight, backend, **backend_kwargs)
#       2 import collections
#       3 import gzip
# ----> 4 import inspect
#       5 import itertools
#       6 import re
#
# File ~/Documents/welfare_clustering/cplex-env/lib/python3.10/site-packages/networkx/utils/backends.py:967, in _dispatchable.__call__(self, backend, *args, **kwargs)
#     965     if backend is not None and backend != "networkx":
#     966         raise ImportError(f"'{backend}' backend is not installed")
# --> 967     return self.orig_func(*args, **kwargs)
#     969 # Use `backend_name` in this function instead of `backend`.
#     970 # This is purely for aesthetics and to make it easier to search for this
#     971 # variable since "backend" is used in many comments and log/error messages.
#     972 backend_name = backend
#
# File ~/Documents/welfare_clustering/cplex-env/lib/python3.10/site-packages/networkx/algorithms/flow/networksimplex.py:609, in network_simplex(G, demand, capacity, weight)
#     604 ###########################################################################
#     605 # Infeasibility and unboundedness detection
#     606 ###########################################################################
#     608 if any(DEAF.edge_flow[i] != 0 for i in range(-n, 0)):
# --> 609     raise nx.NetworkXUnfeasible("no flow satisfies all node demands")
#     611 if any(DEAF.edge_flow[i] * 2 >= faux_inf for i in range(DEAF.edge_count)) or any(
#     612     e[-1].get(capacity, inf) == inf and e[-1].get(weight, 0) < 0
#     613     for e in nx.selfloop_edges(G, data=True)
#     614 ):
#     615     raise nx.NetworkXUnbounded("negative cycle with infinite capacity found")
#
# NetworkXUnfeasible: no flow satisfies all node demands

# %%
import matplotlib.pyplot as plt

def plot_group_distance_costs(data, centers, assignment_matrix, group_labels, group_names=None):
    """
    Plots average squared distance to assigned center for each group.

    Parameters:
    - data: ndarray (n, d) of input points
    - centers: ndarray (k, d) of cluster centers
    - assignment_matrix: binary (n, k) array from rounding
    - group_labels: array of group ids (e.g., 1 or 2)
    - group_names: optional list of names for each group id
    """

    n, k = assignment_matrix.shape
    assigned_centers = assignment_matrix @ centers  # (n, d)
    sq_dists = np.sum((data - assigned_centers)**2, axis=1)  # (n,)

    unique_groups = np.unique(group_labels)
    costs = []

    for h in unique_groups:
        mask = (group_labels == h)
        avg_cost = np.mean(sq_dists[mask])
        costs.append(avg_cost)

    # Prepare x-axis labels
    if group_names:
        labels = [group_names[h - 1] for h in unique_groups]  # assuming group ids are 1-indexed
    else:
        labels = [f"Group {h}" for h in unique_groups]

    # Plot
    plt.figure(figsize=(6, 4))
    plt.bar(labels, costs, color='skyblue', edgecolor='black')
    plt.ylabel("Avg. Distance Cost")
    plt.title("Average Distance-to-Center Cost by Group")
    plt.tight_layout()
    plt.grid(axis='y', linestyle='--', alpha=0.5)
    plt.show()

# %%
plot_group_distance_costs(
    data=data_normalized,
    centers=centers,
    assignment_matrix=result["assignment"],
    group_labels=svar_all,
    group_names=['Female', 'Male']
)
